# %%
# Dictinary are mutable

# %%
employee = {
    1 : 'John',
    2 : 'Andrew',
    3 : 'MikeHrtz',
    4 : 'SamAlth'
}
employee
# Out:
# {1: 'John', 2: 'Andrew', 3: 'MikeHrtz', 4: 'SamAlth'}

# %%
# keys
employee.keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
# VALUES 
employee.values()
# Out:
# dict_values(['John', 'Andrew', 'MikeHrtz', 'SamAlth'])

# %%
copy_employee = employee.copy()
copy_employee
# Out:
# {1: 'John', 2: 'Andrew', 3: 'MikeHrtz', 4: 'SamAlth'}

# %%
# get()
copy_employee.get(3) #pass key
# Out:
# 'MikeHrtz'

# %%
print(copy_employee.get(5)) #pass unknown key
# Out:
# None

# %%
print(copy_employee.get(5 , 'Not Found'))
# Out:
# Not Found

# %%
copy_employee.setdefault(5 , 'JJ')
# Out:
# 'JJ'

# %%
employee = copy_employee
employee
# Out:
# {1: 'John', 2: 'Andrew', 3: 'MikeHrtz', 4: 'SamAlth', 5: 'JJ'}

# %%
emp = {1: 'John', 2: 'Andrew', 3: 'MikeHrtz', 4: 'SamAlth', 5: 'JJ'}
removed = emp.pop(4)
removed
# Out:
# 'SamAlth'

# %%
emp
# Out:
# {1: 'John', 2: 'Andrew', 3: 'MikeHrtz', 5: 'JJ'}

# %%
print('value remove',emp.popitem()) #popitem last element remove krta ha
print(type(emp.popitem()))
print(type(emp))
# Out:
# value remove (5, 'JJ')
# <class 'tuple'>
# <class 'dict'>

# %%
emp.clear()
emp
# Out:
# {}

# %%
employee = {
    1 : 'John',
    2 : 'Andrew',
    3 : 'MikeHrtz',
    4 : 'SamAlth'
}
employee.items()
# Out:
# dict_items([(1, 'John'), (2, 'Andrew'), (3, 'MikeHrtz'), (4, 'SamAlth')])

# %%
type(employee.items())
# Out:
# dict_items

# %%
for k , v in employee.items():
    print(k , v)
# Out:
# 1 John
# 2 Andrew
# 3 MikeHrtz
# 4 SamAlth
