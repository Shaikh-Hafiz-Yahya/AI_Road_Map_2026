# %%
print('Yes I can Learn Python')
# Out:
# Yes I can Learn Python

# %%
print(2+5)
# Out:
# 7

# %%
2+5
# Out:
# 7

# %%
print('2+5')
# Out:
# 2+5

# %%
'2+5'
# Out:
# '2+5'

# %%
"hello"
# Out:
# 'hello'

# %%
print("hello")
# Out:
# hello

# %%
# This is a comment

# %%
print('He said'Yes I can do it'') #error
# Out:
#   Cell In[9], line 1
#     print('He said'Yes I can do it'') #error
#                    ^
# SyntaxError: invalid syntax. Is this intended to be part of the string?

# %%
print("He Said'Yes I Can Do It'") #solve error
# Out:
# He Said'Yes I Can Do It'

# %%
print("He Said\'Yes I Can Do It") #solve error
# Out:
# He Said'Yes I Can Do It

# %%
print("He Said"Yes I Can Do It"") #error

# %%
print("He Said\"Yes I Can Do It") #Solve Error
# Out:
# He Said"Yes I Can Do It

# %%
# print('I'm going to USA') ---> Error

# %%
print("I'm going to USA") #solve error
# Out:
# I'm going to USA

# %%
print('I\'m going to USA')#solve error
# Out:
# I'm going to USA

# %%
print("C:\Users\NewFolder") #Error
# Out:
#   Cell In[17], line 1
#     print("C:\Users\NewFolder") #Error
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# Solve Above Error using ---> r(r means row)
print(r"C:\Users\NewFolder") #Clear Error; Now Same Link Display your Screen
# Out:
# C:\Users\NewFolder

# %%
# agr front slash(/) ha No Need --> r(r row)
print('C:/User/NewFolder')
# Out:
# C:/User/NewFolder

# %%
print('print() is a function')
# Out:
# print() is a function

# %% [markdown]
# ## Arthematic OPerators

# %%
print('Adddition =' , 10+1)
# Out:
# Adddition = 11

# %%
print('Subtraction =' , 10-2)
# Out:
# Subtraction = 8

# %%
print('Multiplication =' , 2*4)
# Out:
# Multiplication = 8

# %%
print('Division =' , 2/10)
# Out:
# Division = 0.2

# %%
print('Floor Division = Decimal Reduce' , 2//10)
# Out:
# Floor Division = Decimal Reduce 0

# %%
# Order change hone se answer bhi change ho jata hai.
# 5 % 2 ≠ 2 % 5
print('Modulus =' , 5%2)
print('Modulus =' , 2%5)
# Out:
# Modulus = 1
# Modulus = 2

# %%
print('Exponent =' , 2**3)
# Out:
# Exponent = 8
