# %%
import array
Array = array.array('i' , [100 , 101 , 110 , 1000 , 1001])
Array
# Out:
# array('i', [100, 101, 110, 1000, 1001])

# %%
# OR 
from array import *
Array = array('i' , [100 , 101 , 200 , 201 , 300])
Array
# Out:
# array('i', [100, 101, 200, 201, 300])

# %%
Array.insert(1 , 150)
Array
# Out:
# array('i', [100, 150, 101, 200, 201, 300])

# %%
Array.append(1000)
Array
# Out:
# array('i', [100, 150, 101, 200, 201, 300, 1000])

# %%
Array.count(1000)
# Out:
# 1

# %%
Array.extend([2000 , 20000 , 50000])
Array
# Out:
# array('i', [100, 150, 101, 201, 300, 1000, 2000, 20000, 50000, 2000, 20000, 50000, 2000, 20000, 50000])

# %%
Array.index(201)
# Out:
# 3

# %% [markdown]
# Difference B/W

# %%
Array[3]
# Out:
# 201

# %%
Array.remove(201)
Array
# Out:
# array('i', [100, 150, 101, 300, 1000, 2000, 20000, 50000, 2000, 20000, 50000, 2000, 20000, 50000])

# %%
# update 
Array[2] = 190
Array
# Out:
# array('i', [100, 150, 190, 300, 1000, 2000, 20000, 50000, 2000, 20000, 50000, 2000, 20000, 50000])

# %%
# Array convert list 
print(Array.tolist())
print(type(Array))
# Out:
# [100, 150, 190, 300, 1000, 2000, 20000, 50000, 2000, 20000, 50000, 2000, 20000, 50000]
# <class 'array.array'>

# %%
Array.pop()
# Out:
# 50000

# %%
#SyntaxError: leading zeros in decimal integer literals are not permitted; 
# use an 0o prefix for octal integers (3235834181.py, line 1)Cell Execution Error
Array.extend([10001 , 0101])
# Out:
#   Cell In[42], line 1
#     Array.extend([10001 , 0101])
#                           ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
Array.extend([10001 , 10101])
Array
# Out:
# array('i', [100, 150, 190, 300, 1000, 2000, 20000, 50000, 2000, 20000, 50000, 2000, 20000, 10001, 10001, 10101, 10001, 10101])

# %%
MyArray = array('i' , [1 , 2 , 3 , 4])
MyArray
# Out:
# array('i', [1, 2, 3, 4])

# %%
NewArray = MyArray
NewArray
# Out:
# array('i', [1, 2, 3, 4])

# %%
MyArray[2] = 5
print(MyArray)
print(NewArray)
# Out:
# array('i', [1, 2, 5, 4])
# array('i', [1, 2, 5, 4])

# %%
copy_array = array('i' , NewArray.tolist())
copy_array
# Out:
# array('i', [1, 2, 5, 4])

# %%
# method 1
copy_array1 = array('i' , NewArray.tolist())
print(copy_array1)
copy_array == copy_array1
# Out:
# array('i', [1, 2, 5, 4])
# True

# %%
# method 2
copy_array2 = array('i' ,( i for i in NewArray))
print(copy_array2)
copy_array1 == copy_array2
# Out:
# array('i', [1, 2, 5, 4])
# <class 'array.array'>
