# %% [markdown]
# min , max , sum k liyay math module import ki need nahi

# %%
min(10000 , 150000 ,2000000 , 30000)
# Out:
# 10000

# %%
max(10000 , 150000 ,2000000 , 30000)
# Out:
# 2000000

# %%
min('a' , 'x' , 's' , 'l')
# Out:
# 'a'

# %%
max('a' , 'x' , 's' , 'l')
# Out:
# 'x'

# %%
sum(10000 , 150000 ,2000000 , 30000) #error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sum(10000 , 150000 ,2000000 , 30000) #error
#
# TypeError: sum() takes at most 2 arguments (4 given)

# %%
sum([10000 , 150000 ,2000000 , 30000]) #solve error
# Out:
# 2190000

# %%
x = 25
x.sqrt(25) #error 
x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 x = 25
# ----> 2 x.sqrt(25)
#       3 x
#
# AttributeError: 'int' object has no attribute 'sqrt'

# %% [markdown]
# ### Now need math module

# %%
import math
x = 25
math.sqrt(x) #error solve
# Out:
# 5.0

# %%
x = math.sqrt(55)
x
# Out:
# 7.416198487095663

# %%
math.floor(x)
# Out:
# 7

# %%
# Decimal ho ya fraction → upar round karta hai
# Already integer ho → wohi number deta hai
math.ceil(1/2)
# Out:
# 1

# %%
math.ceil(1/3)
# Out:
# 1

# %%
math.factorial(5)
# Out:
# 120

# %%
math.asin(0)
# Out:
# 0.0

# %%
math.acos(0)
# Out:
# 1.5707963267948966

# %%
math.acosh(0) #error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 math.acosh(0)
#
# ValueError: expected argument value not less than 1, got 0.0

# %%
math.acosh(1)
# Out:
# 0.0

# %%
math.atanh(0)
# Out:
# 0.0

# %%
math.asinh(0)
# Out:
# 0.0

# %%
math.cbrt(4) #Return the cube root of x.
# Out:
# 1.5874010519681994
