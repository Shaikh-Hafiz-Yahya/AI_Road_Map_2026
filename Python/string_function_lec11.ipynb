# %%
# string fn 
my_str = 'hello python'
print(my_str.upper())
print(my_str.lower())
print(my_str.title())
print(my_str.strip())
# Out:
# HELLO PYTHON
# hello python
# Hello Python
# hello python

# %%
my_str = ' hello python '
my_str.strip()
# Out:
# 'hello python'

# %%
my_str = '  hello python  '
my_str.lstrip() #left side strip
# Out:
# 'hello python  '

# %%
my_str = ' hello python '
my_str.rstrip() #right side strip
# Out:
# ' hello python'

# %%
my_str = ' hello python '
my_str.find('p') #index mily ga
# Out:
# 7

# %%
my_str = 'hello python'
my_str.replace('p' , 't')
# Out:
# 'hello tython'

# %%
len(my_str)
# Out:
# 12

# %%
# str indexing 
collection_of_alphabates = 'Hello Python'
collection_of_alphabates[0]
# Out:
# 'H'

# %%
collection_of_alphabates[0:]
# Out:
# 'Hello Python'

# %%
collection_of_alphabates[3:]
# Out:
# 'lo Python'

# %%
collection_of_alphabates[-1]
# Out:
# 'n'

# %%
collection_of_alphabates[:-1]
# Out:
# 'Hello Pytho'

# %%
collection_of_alphabates[-7:-2]
# Out:
# ' Pyth'

# %%
collection_of_alphabates[2:5]
# Out:
# 'llo'

# %%
# Assignment 
user  = "User123@gmail.com"
user[0:4]
# Out:
# 'User'

# %%
user[4:7]
# Out:
# '123'

# %%
user[7:8]
# Out:
# '@'

# %%
user[7:13]
# Out:
# '@gmail'

# %%
user[13:17]
# Out:
# '.com'
