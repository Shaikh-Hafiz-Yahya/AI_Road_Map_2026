# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Muhammad Yahya\Downloads\python\AI Roadmap2026\Module03 Pandas\student_performance_dataset-selected-columns.csv')
df.columns
# Out:
# Index(['student_id', 'gender', 'study_time_hours', 'attendance_percent',
#        'sleep_hours', 'parental_education', 'internet_access',
#        'extracurricular_activities', 'part_time_job', 'previous_grade'],
#       dtype='object')

# %%
df.previous_grade.unique()
# Out:
# array([ 76.9,  75.5,  88.5,  85.1,  61.8,  79.8,  58.6,  78.4,  63.8,
#         57.7,  73.4,  37.9,  49. ,  67.9,  71. ,  65.6,  51. ,  60.2,
#         74.7,  77. ,  69.8,  83.9,  74.8,  61. ,  66.6,  53.2,  68.7,
#         83.3,  78.2,  86.8,  66.4,  86.2,  67.7,  87.7,  69.7,  78.5,
#         72.6,  85.5,  68.4,  54.1,  95.7,  64.4,  71.9,  62.7,  57.9,
#         73. ,  48.5,  66.5,  72.9,  66.8,  51.5,  89.1,  71.2,  87.2,
#         66.9,  59.4,  73.2,  67.4,  55.9,  87.6,  62.5,  47.9,  85.9,
#         63.9,  48.8,  90.9,  54.5,  70.7,  81. ,  75.1,  69.3,  49.6,
#         60.3,  72.3,  60.6,  72.4,  81.6,  55.3,  96.4,  79.2,  70. ,
#         83.1,  98.4,  52.7,  67.3,  41.5,  74.4,  69.5,  62.1,  45.4,
#         74.5,  87.5,  62.9,  75.3,  51.2,  65.3,  60.9,  74.6,  54.3,
#         65.2,  56.8,  91.6,  59.8,  62. ,  58.3,  76.6,  58.8,  73.1,
#         65.9,  74.1,  63.5,  91.8,  54.8,  88.4,  73.6,  80. ,  62.4,
# ...

# %%
df.attendance_percent.value_counts()
# Out:
# attendance_percent
# 100.0    70
# 85.2      9
# 90.1      8
# 91.7      8
# 78.5      8
#          ..
# 95.5      1
# 90.3      1
# 76.4      1
# 71.3      1
# 67.9      1
# Name: count, Length: 327, dtype: int64

# %%
df[df['attendance_percent'] >= 99]
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 1             2  Female               6.3               100.0          5.7
# 6             7    Male               1.5               100.0          5.0
# 21           22    Male               3.3               100.0          7.8
# 27           28  Female               5.4               100.0          5.7
# 32           33  Female               5.3               100.0          7.3
# ..          ...     ...               ...                 ...          ...
# 919         920  Female               2.2               100.0          8.1
# 925         926    Male               4.7               100.0          7.3
# 937         938    Male               4.2               100.0          7.1
# 979         980  Female               3.3               100.0          9.1
# 989         990  Female               3.2                99.5          5.6
#
#     parental_education internet_access extracurricular_activities  \
# ...
